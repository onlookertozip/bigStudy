# %% [markdown]
# <a href="https://colab.research.google.com/github/onlookertozip/bigStudy/blob/master/%EB%8D%B0%EC%9D%B4%ED%84%B0%EA%B0%80%EA%B3%B5_%EC%98%88%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import platform

from matplotlib import font_manager, rc

plt.rcParams['axes.unicode_minus'] = False



if( platform.system() =='Darwin' ):

    rc( 'font', family='AppleGothic' )

elif( platform.system() == 'Windows' ):

    path='c:/Windows/Fonts/malgun.ttf'

    font_name= font_manager.FontProperties( fname=path ).get_name()

    rc('font',family=font_name)

else:

    print('error')
# Out:
# error

# %% [markdown]
# 데이터 적재(1)-라이브러리 데이터 셋 로드

# %%
# 보스턴 데이터 셋 로드
from sklearn.datasets import load_boston

# %%
boston=load_boston()

boston.data.shape
# Out:
# (506, 13)

# %%
boston_features=boston.data

boston_features[0]
# Out:
# array([6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#        6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#        4.980e+00])

# %%
boston_features[0:4]
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, 0.0000e+00, 5.3800e-01,
#         6.5750e+00, 6.5200e+01, 4.0900e+00, 1.0000e+00, 2.9600e+02,
#         1.5300e+01, 3.9690e+02, 4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, 0.0000e+00, 4.6900e-01,
#         6.4210e+00, 7.8900e+01, 4.9671e+00, 2.0000e+00, 2.4200e+02,
#         1.7800e+01, 3.9690e+02, 9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, 0.0000e+00, 4.6900e-01,
#         7.1850e+00, 6.1100e+01, 4.9671e+00, 2.0000e+00, 2.4200e+02,
#         1.7800e+01, 3.9283e+02, 4.0300e+00],
#        [3.2370e-02, 0.0000e+00, 2.1800e+00, 0.0000e+00, 4.5800e-01,
#         6.9980e+00, 4.5800e+01, 6.0622e+00, 3.0000e+00, 2.2200e+02,
#         1.8700e+01, 3.9463e+02, 2.9400e+00]])

# %%
# head() 함수 이용해 행 조회
import pandas as pd

# %%
boston_df=pd.DataFrame(boston_features)

boston_df.head()
# Out:
#         0     1     2    3      4   ...   8      9     10      11    12
# 0  0.00632  18.0  2.31  0.0  0.538  ...  1.0  296.0  15.3  396.90  4.98
# 1  0.02731   0.0  7.07  0.0  0.469  ...  2.0  242.0  17.8  396.90  9.14
# 2  0.02729   0.0  7.07  0.0  0.469  ...  2.0  242.0  17.8  392.83  4.03
# 3  0.03237   0.0  2.18  0.0  0.458  ...  3.0  222.0  18.7  394.63  2.94
# 4  0.06905   0.0  2.18  0.0  0.458  ...  3.0  222.0  18.7  396.90  5.33
#
# [5 rows x 13 columns]

# %%
boston_df.head(7)
# Out:
#         0     1     2    3      4   ...   8      9     10      11     12
# 0  0.00632  18.0  2.31  0.0  0.538  ...  1.0  296.0  15.3  396.90   4.98
# 1  0.02731   0.0  7.07  0.0  0.469  ...  2.0  242.0  17.8  396.90   9.14
# 2  0.02729   0.0  7.07  0.0  0.469  ...  2.0  242.0  17.8  392.83   4.03
# 3  0.03237   0.0  2.18  0.0  0.458  ...  3.0  222.0  18.7  394.63   2.94
# 4  0.06905   0.0  2.18  0.0  0.458  ...  3.0  222.0  18.7  396.90   5.33
# 5  0.02985   0.0  2.18  0.0  0.458  ...  3.0  222.0  18.7  394.12   5.21
# 6  0.08829  12.5  7.87  0.0  0.524  ...  5.0  311.0  15.2  395.60  12.43
#
# [7 rows x 13 columns]

# %%
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       506 non-null    float64
#  1   1       506 non-null    float64
#  2   2       506 non-null    float64
#  3   3       506 non-null    float64
#  4   4       506 non-null    float64
#  5   5       506 non-null    float64
#  6   6       506 non-null    float64
#  7   7       506 non-null    float64
#  8   8       506 non-null    float64
#  9   9       506 non-null    float64
#  10  10      506 non-null    float64
#  11  11      506 non-null    float64
#  12  12      506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %%
boston_df.columns
# Out:
# RangeIndex(start=0, stop=13, step=1)

# %%
#Diabetes 데이터 셋 로드

from sklearn.datasets import load_diabetes
diabetes=load_diabetes()
diabetes.data.shape
# Out:
# (442, 10)

# %%
# Optical recognition of handwritten digits데이터 셋 로드

from sklearn.datasets import load_digits
digits=load_digits()
digits.data.shape
# Out:
# (1797, 64)

# %%
digits.data[0]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
import matplotlib.pyplot as plt

# %%
plt.gray()
plt.matshow(digits.images[0])
plt.show()

# %%
digits.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'images', 'DESCR'])

# %%
digits['DESCR'][:70]
# Out:
# '.. _digits_dataset:\n\nOptical recognition of handwritten digits dataset'

# %%
#iris 데이터 셋 로드
from sklearn.datasets import load_iris
iris_features=load_iris()

iris_features.data.shape
# Out:
# (150, 4)

# %%
iris_features.data[0]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
iris_features.data[0:4]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2]])

# %%
iris_df=pd.DataFrame(iris_features.data)

# %%
iris_df.head()
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       150 non-null    float64
#  1   1       150 non-null    float64
#  2   2       150 non-null    float64
#  3   3       150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
iris_features.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
list(iris_features.target_names)
# Out:
# ['setosa', 'versicolor', 'virginica']

# %%
list(iris_features.feature_names)
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
print(iris_features) # 로드된 데이터가 속성-스타일 접근을 제공하는 딕셔너리와 번치 객체로 표현된 것을 확인
print(iris_features.DESCR) # Description 속성을 이용해서 데이터셋의 정보를 확인

# 각 key에 저장된 value 확인
# feature
print(iris_features.data)
print(iris_features.feature_names)

# label
print(iris_features.target)
print(iris_features.target_names)

# %%
import pandas as pd
import numpy as np

iris_df2=pd.DataFrame(data=iris_features.data, columns=iris_features.feature_names)
iris_df2['target']=iris_features.target

iris_df2['target']=iris_df2['target'].map({0:"setosa", 1:"versicolor", 2:"virginica"})

# %%
print(iris_df2)
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)     target
# 0                  5.1               3.5  ...               0.2     setosa
# 1                  4.9               3.0  ...               0.2     setosa
# 2                  4.7               3.2  ...               0.2     setosa
# 3                  4.6               3.1  ...               0.2     setosa
# 4                  5.0               3.6  ...               0.2     setosa
# ..                 ...               ...  ...               ...        ...
# 145                6.7               3.0  ...               2.3  virginica
# 146                6.3               2.5  ...               1.9  virginica
# 147                6.5               3.0  ...               2.0  virginica
# 148                6.2               3.4  ...               2.3  virginica
# 149                5.9               3.0  ...               1.8  virginica
#
# [150 rows x 5 columns]

# %%
# 사이킷런에 있는 데이터셋을 이용 모의 데이터셋 만들기

#1. make_regression을 이용한 선형회귀에 사용할 데이터 셋 만들기
# 라이브러리를 임포트합니다.
from sklearn.datasets import make_regression

# 특성 행렬, 타깃 벡터, 정답 계수를 생성합니다.
features, target, coefficients = make_regression(n_samples = 100,
                                                 n_features = 3,
                                                 n_informative = 3,
                                                 n_targets = 1,
                                                 noise = 0.0,
                                                 coef = True,
                                                 random_state = 1)

# 특성 행렬과 타깃 벡터를 확인합니다.
print('특성 행렬\n', features[:3])
print('타깃 벡터\n', target[:3])
# Out:
# 특성 행렬
#  [[ 1.29322588 -0.61736206 -0.11044703]
#  [-2.793085    0.36633201  1.93752881]
#  [ 0.80186103 -0.18656977  0.0465673 ]]
# 타깃 벡터
#  [-10.37865986  25.5124503   19.67705609]

# %%
# 2. make_classification을 이용한 분류에 필요한 데이터셋 만들기

# 라이브러리를 임포트합니다.
from sklearn.datasets import make_classification

# 특성 행렬과 타깃 벡터를 생성합니다.
features, target = make_classification(n_samples = 100,
                                       n_features = 3,
                                       n_informative = 3,
                                       n_redundant = 0,
                                       n_classes = 2,
                                       weights = [.25, .75],
                                       random_state = 1)

# 특성 행렬과 타깃 벡터를 확인합니다.
print('특성 행렬\n', features[:3])
print('타깃 벡터\n', target[:3])
# Out:
# 특성 행렬
#  [[ 1.06354768 -1.42632219  1.02163151]
#  [ 0.23156977  1.49535261  0.33251578]
#  [ 0.15972951  0.83533515 -0.40869554]]
# 타깃 벡터
#  [1 0 0]

# %%
# 3. make_blobs을 이용한 군집에 필요한 데이터 셋 만들기

# 라이브러리를 임포트합니다.
from sklearn.datasets import make_blobs

# 특성 행렬과 타깃 벡터를 생성합니다.
features, target = make_blobs(n_samples = 100,
                              n_features = 2,
                              centers = 3,
                              cluster_std = 0.5,
                              shuffle = True,
                              random_state = 1)

# 특성 행렬과 타깃 벡터를 확인합니다.
print('특성 행렬\n', features[:3])
print('타깃 벡터\n', target[:3])
# Out:
# 특성 행렬
#  [[ -1.22685609   3.25572052]
#  [ -9.57463218  -4.38310652]
#  [-10.71976941  -4.20558148]]
# 타깃 벡터
#  [0 1 1]

# %%
# 4. make_blobs을 이용한 군집 데이터 셋 그림으로 확인

import matplotlib.pyplot as plt

plt.scatter(features[:,0], features[:,1], c=target)
plt.show()

# %% [markdown]
# 데이터 적재(2)-물리적인 파일 데이터 셋 로드

# %%
# !git clone https://github.com/onlookertozip/bigStudy.git

# %%
import pandas as pd

# %%
url='diamonds.csv'

# %%
diamonds_df=pd.read_csv(url)

# %%
diamonds_df.head(5)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds_df.tail(5)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
print(diamonds_df)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds_11=pd.read_csv(url, skiprows=range(1,11), nrows=5)
diamonds_11
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.30     Good     J     SI1   64.0     55    339  4.25  4.28  2.73
# 1   0.23    Ideal     J     VS1   62.8     56    340  3.93  3.90  2.46
# 2   0.22  Premium     F     SI1   60.4     61    342  3.88  3.84  2.33
# 3   0.31    Ideal     J     SI2   62.2     54    344  4.35  4.37  2.71
# 4   0.20  Premium     E     SI2   60.2     62    345  3.79  3.75  2.27

# %%
import pandas as pd

# %%
url='diamonds.xlsx'

# %%
diamonds_xl=pd.read_excel(url, sheet_name=0, header=0)

# %%
print(diamonds_xl)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds_xl.head(5)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# # json 파일 사용

# %%
import csv
import json

# %%
csvfile=open('diamonds.csv','r')
jsonfile=open('diamonds.json','w')

# %%
fieldnames=("FirstName","LastName","IDNumber","Message")
reader=csv.DictReader(csvfile, fieldnames)

# %%
out=json.dumps([row for row in reader])
jsonfile.write(out)
# Out:
# 7303173

# %%
import pandas as pd

url='diamonds.json'

diamonds_json=pd.read_json(url, orient='columns')

# %%
diamonds_json.head(5)
# Out:
#   FirstName LastName IDNumber  Message                               null
# 0     carat      cut    color  clarity     [depth, table, price, x, y, z]
# 1      0.23    Ideal        E      SI2  [61.5, 55, 326, 3.95, 3.98, 2.43]
# 2      0.21  Premium        E      SI1  [59.8, 61, 326, 3.89, 3.84, 2.31]
# 3      0.23     Good        E      VS1  [56.9, 65, 327, 4.05, 4.07, 2.31]
# 4      0.29  Premium        I      VS2   [62.4, 58, 334, 4.2, 4.23, 2.63]

# %%
pip install pymysql
# Out:
# ...
#      |████████████████████████████████| 51kB 2.5MB/s
# ...

# %%
#MariaDB 에접속
import pandas as pd
import pymysql

conn=pymysql.connect(host='127.0.0.1', port=3306, user='root', password='mariadb', database='mysql')

rs=pd.read_sql('show tables', conn)

rs.head()
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pymysql/connections.py in connect(self, sock)
#     613                             sock = socket.create_connection(
# --> 614                                 (self.host, self.port), self.connect_timeout, **kwargs
#     615                             )
#
# /usr/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#
# /usr/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# CSV파일 내보내기

import pandas as pd
import matplotlib as mp
from matplotlib import pyplot as plt

file_survey=pd.read_csv("C:\\Users\\dec2819\\Downloads\\1-2019-N_사전설문.csv", encoding="cp949")

#혹은
scores=pd.read_csv("C:\\Users\\dec2819\\Downloads\\1-2019-N_직업기초능력_교육이수및능력점수.csv", encoding="utf-8")

file_survey.head()

file_survey.isnull().sum()

fillna_survey=file_survey.fillna(0)

fillna_survey.isnull().sum()

import pandas as pd
from pandas import DataFrame

fillna_survey.to_csv('C:\\DEV\\fillna_survey.csv', # file path, file name
sep=',',   # seperator, delimiter (구분자)
index = True,
encoding="cp949",
na_rep='NaN')   # missing data representation (결측값 표기)

# %% [markdown]
# # 데이터 랭글링

# %%
# 데이터 전처리 간단한 예

from sklearn.datasets import load_digits
import seaborn as sns
import matplotlib as mp
import matplotlib.pyplot as plt

digits = load_digits()
sns.heatmap(digits.images[0], cmap=mp.cm.bone_r, annot=True, fmt="2.0f",
            cbar=True, xticklabels=False, yticklabels=False)
plt.title("MNIST 숫자 이미지 표본")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49707 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
# 8X8

digits.images[0]
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
# 64

digits.images[0].flatten()
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
import pandas as pd

url='titanic.csv'

titanic_csv=pd.read_csv(url)

titanic_csv.head(5)
# Out:
#   Class  Gender    Age Survived  Freq
# 0   1st    Male  Child       No     0
# 1   2nd    Male  Child       No     0
# 2   3rd    Male  Child       No    35
# 3  Crew    Male  Child       No     0
# 4   1st  Female  Child       No     0

# %%
# 1. 새로운 데이터 프레임 만들기

import pandas as pd

new_df=pd.DataFrame()

# 열을 추가
new_df['Name']=['Jacson','Steven']
new_df['Age']=[40, 25]
new_df['Driver']=[True, False]

new_df
# Out:
#      Name  Age  Driver
# 0  Jacson   40    True
# 1  Steven   25   False

# %%
add_df=pd.Series(['Smith',55, True], index=['Name','Age','Driver'])

new_df.append(add_df, ignore_index=True)
# Out:
#      Name  Age  Driver
# 0  Jacson   40    True
# 1  Steven   25   False
# 2   Smith   55    True

# %% [markdown]
# 데이터 조회 혹은 설명하기

# %%
import pandas as pd

url='titanic.csv'

titanic_csv=pd.read_csv(url)

titanic_csv.head(5)
# Out:
#   Class  Gender    Age Survived  Freq
# 0   1st    Male  Child       No     0
# 1   2nd    Male  Child       No     0
# 2   3rd    Male  Child       No    35
# 3  Crew    Male  Child       No     0
# 4   1st  Female  Child       No     0

# %%
# 차원 확인

titanic_csv.shape
# Out:
# (32, 5)

# %%
# 기술 통계값 요약

titanic_csv.describe()
# Out:
#              Freq
# count   32.000000
# mean    68.781250
# std    135.995905
# min      0.000000
# 25%      0.750000
# 50%     13.500000
# 75%     77.000000
# max    670.000000

# %%
# 데이터 프레임에 대한 탐색

# 첫 번째 행을 선택
titanic_csv.iloc[0]
# Out:
# Class         1st
# Gender       Male
# Age         Child
# Survived       No
# Freq            0
# Name: 0, dtype: object

# %%
titanic_csv.head(1)
# Out:
#   Class Gender    Age Survived  Freq
# 0   1st   Male  Child       No     0

# %%
titanic_csv.head(4)
# Out:
#   Class Gender    Age Survived  Freq
# 0   1st   Male  Child       No     0
# 1   2nd   Male  Child       No     0
# 2   3rd   Male  Child       No    35
# 3  Crew   Male  Child       No     0

# %%
titanic_csv.iloc[0:4]
# Out:
#   Class Gender    Age Survived  Freq
# 0   1st   Male  Child       No     0
# 1   2nd   Male  Child       No     0
# 2   3rd   Male  Child       No    35
# 3  Crew   Male  Child       No     0

# %%
titanic_csv.iloc[:4]
# Out:
#   Class Gender    Age Survived  Freq
# 0   1st   Male  Child       No     0
# 1   2nd   Male  Child       No     0
# 2   3rd   Male  Child       No    35
# 3  Crew   Male  Child       No     0

# %%
# 인덱스를 이용해 조회하기

titanic_idx=titanic_csv.set_index(titanic_csv['Class'])

titanic_idx.loc['1st']
# Out:
#       Class  Gender    Age Survived  Freq
# Class
# 1st     1st    Male  Child       No     0
# 1st     1st  Female  Child       No     0
# 1st     1st    Male  Adult       No   118
# 1st     1st  Female  Adult       No     4
# 1st     1st    Male  Child      Yes     5
# 1st     1st  Female  Child      Yes     1
# 1st     1st    Male  Adult      Yes    57
# 1st     1st  Female  Adult      Yes   140

# %%
# 조회 시 조건을 주고 조회하기

titanic_csv[(titanic_csv['Gender']=='Female') & (titanic_csv['Age']=='Child')]
# Out:
#    Class  Gender    Age Survived  Freq
# 4    1st  Female  Child       No     0
# 5    2nd  Female  Child       No     0
# 6    3rd  Female  Child       No    17
# 7   Crew  Female  Child       No     0
# 20   1st  Female  Child      Yes     1
# 21   2nd  Female  Child      Yes    13
# 22   3rd  Female  Child      Yes    14
# 23  Crew  Female  Child      Yes     0

# %% [markdown]
# 값 치환
# 데이터프레임에 있는 값을 바꾸어야 하는 경우

# %%
import pandas as pd

url='titanic.csv'

titanic_csv=pd.read_csv(url)

# %%
# 값을 치환
titanic_csv['Gender'].replace('Female','Woman').head(2)
# Out:
# 0    Male
# 1    Male
# Name: Gender, dtype: object

# %%
titanic_csv['Gender'].replace("Female","Woman").head(2)
# Out:
# 0    Male
# 1    Male
# Name: Gender, dtype: object

# %%
titanic_csv['Gender'].replace(["Female","Male"],["Woman","Man"]).head(5)
# Out:
# 0      Man
# 1      Man
# 2      Man
# 3      Man
# 4    Woman
# Name: Gender, dtype: object

# %%
titanic_csv['Gender'].replace(['Female','Male'],['Woman','Man']).head(5)
# Out:
# 0      Man
# 1      Man
# 2      Man
# 3      Man
# 4    Woman
# Name: Gender, dtype: object

# %%
titanic_csv.head(5)
# Out:
#   Class  Gender    Age Survived  Freq
# 0   1st    Male  Child       No     0
# 1   2nd    Male  Child       No     0
# 2   3rd    Male  Child       No    35
# 3  Crew    Male  Child       No     0
# 4   1st  Female  Child       No     0

# %%
titanic_csv.replace(0, "Zero").head(5)
# Out:
#   Class  Gender    Age Survived  Freq
# 0   1st    Male  Child       No  Zero
# 1   2nd    Male  Child       No  Zero
# 2   3rd    Male  Child       No    35
# 3  Crew    Male  Child       No  Zero
# 4   1st  Female  Child       No  Zero

# %%
# 정규식
titanic_csv.replace(r"1st", "First", regex=True).head(5)
# Out:
#    Class  Gender    Age Survived  Freq
# 0  First    Male  Child       No     0
# 1    2nd    Male  Child       No     0
# 2    3rd    Male  Child       No    35
# 3   Crew    Male  Child       No     0
# 4  First  Female  Child       No     0

# %%
# Qiuz : Female을 1로 바꾸고 Male을 0으로 바꾸어 보시오.

titanic_csv.replace({"Female":1, "Male":0}).head(5)
# Out:
#   Class  Gender    Age Survived  Freq
# 0   1st       0  Child       No     0
# 1   2nd       0  Child       No     0
# 2   3rd       0  Child       No    35
# 3  Crew       0  Child       No     0
# 4   1st       1  Child       No     0

# %% [markdown]
# 열(컬럼) 이름 변경

# %%
titanic_csv.rename(columns={'Class':'CustomerClass'}).head(5)
# Out:
#   CustomerClass  Gender    Age Survived  Freq
# 0           1st    Male  Child       No     0
# 1           2nd    Male  Child       No     0
# 2           3rd    Male  Child       No    35
# 3          Crew    Male  Child       No     0
# 4           1st  Female  Child       No     0
